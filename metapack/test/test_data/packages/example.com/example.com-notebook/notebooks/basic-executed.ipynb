# %%
#2018-04-01 13:47:39.947542
# %load_ext metapack.jupyter.magic

# %%
import pandas as pd
import numpy as np
import random

# %%
N = 2500

dfa = pd.DataFrame({
        'int1': range(0,N),
        'float2': np.linspace(0,1,N),
        'str3': np.random.choice( list('abcdefghij'), N) 
        
    })

# %%
dfb = dfa.copy()*2

# %%
# %mt_materialize dfb /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmp0ip91m1l
# Out:
# {
#     "df_name": "dfb",
#     "path": "/var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmp0ip91m1l/dfb.csv"
# }

# %%
# %mt_materialize_all /var/folders/_8/4x14kzy53_9fxgt_b42thm200000gn/T/tmp0ip91m1l
# Out:
# []

# %%
# %mt_show_metatab
# Out:
# Declare: metatab-latest
# Section: Resources

# %%
# %mt_show_libdirs
# Out:
# []
